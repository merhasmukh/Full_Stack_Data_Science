# %%
# !pip install mysql-connector-python
# Out:
# ...
#      |████████████████████████████████| 23.5 MB 21.7 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 1.0 MB 62.9 MB/s eta 0:00:01
# ...

# %%
import mysql.connector as connection

# %%
import mysql.connector as connection

try:
    mydb=connection.connect(host="localhost",user="abc",passwd="password",use_pure=True)
    query="show databases;"

    cursor=mydb.cursor()
    cursor.execute(query)
    print(cursor.fetchall())
except Exception as e:
    print(e)
    mydb.close()
# Out:
# [('information_schema',), ('mysql',), ('performance_schema',), ('sys',)]

# %%
conn=connection.connect(host="localhost",user="abc",passwd="password",use_pure=True)
cursor=conn.cursor()
cursor.execute("show databases")
res= cursor.fetchall()

# %%
res= cursor.fetchall()
# cursor.fetchall()

# %%
res
# Out:
# []

# %%
res[0][0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [9], line 1
# ----> 1 res[0][0]
#
# IndexError: list index out of range

# %%
for i in res:
    print(i[0])

# %%
import mysql.connector as connection

try:
    mydb=connection.connect(host="localhost",user="abc",passwd="password",use_pure=True)
    query="create database student;"

    cursor=mydb.cursor()
    cursor.execute(query)
    print("databse created..!!")
    mydb.close()
    # print(cursor.fetchall())
except Exception as e:
    print(e)
    mydb.close()
# Out:
# databse created..!!

# %%
conn=connection.connect(host="localhost",user="abc",passwd="password",use_pure=True)
cursor=conn.cursor()
cursor.execute("show databases")
res= cursor.fetchall()
res
# Out:
# [('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('student',),
#  ('sys',)]

# %%
import mysql.connector as connection 

try:
    mydb=connection.connect(host="localhost",database="student",user="abc",passwd="password",use_pure=True)

    print(mydb.is_connected())

    query="create table StudentDetails (Studentid INT(10) AUTO_INCREMENT PRIMARY KEY , FirstName VARCHAR(60)," \
        "LastName VARCHAR(60), RegistrationDate DATE,Class VARCHAR(20), Section VARCHAR(10))"

    cursor = mydb.cursor()
    cursor.execute(query)
    mydb.close()

except Exception as e:
    mydb.close()
    print(str(e))
# Out:
# True

# %%
conn=connection.connect(host="localhost",user="abc",passwd="password",use_pure=True)
cursor=conn.cursor()
cursor.execute("show databases")
res= cursor.fetchall()
res
# Out:
# [('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('student',),
#  ('sys',)]

# %%
import mysql.connector as connection 

try:
    mydb=connection.connect(host="localhost",database="student",user="abc",passwd="password",use_pure=True)

    print(mydb.is_connected())

    query="create table test (x1 INT(5),x2 VARCHAR(20),x3 DATE)"

    cursor = mydb.cursor()
    cursor.execute(query)
    mydb.close()

except Exception as e:
    mydb.close()
    print(str(e))
# Out:
# True

# %%
import mysql.connector as connection 

try:
    mydb=connection.connect(host="localhost",database="student",user="abc",passwd="password",use_pure=True)

    print(mydb.is_connected())

    query="select * from test"

    cursor = mydb.cursor()
    cursor.execute(query)
    print(cursor.fetchall())

    mydb.close()

except Exception as e:
    mydb.close()
    print(str(e))
# Out:
# True
# []

# %%
import mysql.connector as connection 

try:
    mydb=connection.connect(host="localhost",database="student",user="abc",passwd="password",use_pure=True)

    print(mydb.is_connected())

    query="insert into test values(100,'hasmukh','2022-10-25')"

    cursor = mydb.cursor()
    cursor.execute(query)
    mydb.commit()
    print(cursor.fetchall())

    mydb.close()

except Exception as e:
    mydb.close()
    print(str(e))
# Out:
# True
# []

# %%
import mysql.connector as connection 

try:
    mydb=connection.connect(host="localhost",database="student",user="abc",passwd="password",use_pure=True)

    print(mydb.is_connected())

    query="select * from test"

    cursor = mydb.cursor()
    cursor.execute(query)
    print(cursor.fetchall())

    mydb.close()

except Exception as e:
    mydb.close()
    print(str(e))
# Out:
# True
# [(100, 'hasmukh', datetime.date(2022, 10, 25))]

# %%
import pandas as pd

# %%
# !pip install pandas

# %%
mydb

# %%
mydb=connection.connect(host="localhost",database="student",user="abc",passwd="password",use_pure=True)

# %%
import pandas as pd

# %%
a =pd.read_sql("select * from test",mydb)
# Out:
# /tmp/ipykernel_3553/2844812597.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   a =pd.read_sql("select * from test",mydb)

# %%
a
# Out:
#     x1       x2          x3
# 0  100  hasmukh  2022-10-25

# %%
import csv

# %%
# !ls
# Out:
# carbon_nanotubes.csv  demo.py  mysql.ipynb  README.md  requirements.txt

# %%
with open("./carbon_nanotubes.csv","r+") as fd:
    data_file=csv.reader(fd)
    for i in enumerate(data_file):
        for j in i[1]:
            if i[0]==0:
                col_name=j.split(";")
                print(str(col_name))
            else:
                data=j.split(";")
                print(data)
# Out:
# ['Chiral indice n', 'Chiral indice m', 'Initial atomic coordinate u', 'Initial atomic coordinate v', 'Initial atomic coordinate w', "Calculated atomic coordinates u'", "Calculated atomic coordinates v'", "Calculated atomic coordinates w'"]
# ['2', '1', '0']
# ['679005', '0']
# ['701318', '0']
# ['017033', '0']
# ['721039', '0']
# ['730232', '0']
# ['017014']
# ['2', '1', '0']
# ['717298', '0']
# ['642129', '0']
# ['231319', '0']
# ['738414', '0']
# ['65675', '0']
# ['232369']
# ['2', '1', '0']
# ['489336', '0']
# ['303751', '0']
# ['088462', '0']
# ['477676', '0']
# ['263221', '0']
# ['088712']
# ['2', '1', '0']
# ['413957', '0']
# ['632996', '0']
# ['040843', '0']
# ['408823', '0']
# ['657897', '0']
# ['039796']
# ['2', '1', '0']
# ['334292', '0']
# ['543401', '0']
# ['15989', '0']
# ['303349', '0']
# ['558807', '0']
# ['157373']
# ['2', '1', '0']
# ['510664', '0']
# ['696249', '0']
# ['255128', '0']
# ['496977', '0']
# ['725608', '0']
# ['25597']
# ['2', '1', '0']
# ...

# %%
col_name
# Out:
# ['Chiral indice n',
#  'Chiral indice m',
#  'Initial atomic coordinate u',
#  'Initial atomic coordinate v',
#  'Initial atomic coordinate w',
#  "Calculated atomic coordinates u'",
#  "Calculated atomic coordinates v'",
#  "Calculated atomic coordinates w'"]

# %%
mydb=connection.connect(host="localhost",database="student",user="abc",passwd="password",use_pure=True)
cur=mydb.cursor()
cur.execute("create table carbon_nanotube(Chiral_indice_n float(10),Chiral_indice_m float(10),Initial_atomic_coordinate_u float(10),Initial_atomic_coordinate_v float(10),Initial_atomic_coordinate_w float(10),Calculated_atomic_coordinates_u float(10),Calculated_atomic_coordinates_v float(10),Calculated_atomic_coordinates_w float(10));")
cur.close()
mydb.close()
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In [16], line 3
#       1 mydb=connection.connect(host="localhost",database="student",user="abc",passwd="password",use_pure=True)
#       2 cur=mydb.cursor()
# ----> 3 cur.execute("create table carbon_nanotube(Chiral_indice_n float(10),Chiral_indice_m float(10),Initial_atomic_coordinate_u float(10),Initial_atomic_coordinate_v float(10),Initial_atomic_coordinate_w float(10),Calculated_atomic_coordinates_u float(10),Calculated_atomic_coordinates_v float(10),Calculated_atomic_coordinates_w float(10));")
#       4 cur.close()
#       5 mydb.close()
#
# File ~/.local/lib/python3.8/site-packages/mysql/connector/cursor.py:564, in MySQLCursor.execute(self, operation, params, multi)
#     561     return self._execute_iter(self._connection.cmd_query_iter(stmt))
#     563 try:
# ...

# %%
mydb=connection.connect(host="localhost",database="student",user="abc",passwd="password",use_pure=True)

a =pd.read_sql("select * from carbon_nanotube",mydb)
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [10], line 1
# ----> 1 mydb=connection.connect(host="localhost",database="student",user="abc",passwd="password",use_pure=True)
#       3 a =pd.read_sql("select * from carbon_nanotube",mydb)
#       4 a
#
# NameError: name 'connection' is not defined

# %%
import csv
from mysql.connector import connection
with open("./carbon_nanotubes.csv","r+") as fd:
    data_file=csv.reader(fd)
    # mydb=connection.connect(host="localhost",database="student",user="abc",passwd="password",use_pure=True)
    # cur=mydb.cursor()
    for i in enumerate(data_file):
        all_data=[]
        for j in i[1]:
            if i[0]==0:
                col_name=j.split(";")
                # prinmport csv
# from mysql.connector import connectiont(str(col_name))
            else:
                
                
                # print(type(j))
                if ";" in j:
                    j=j.split(";")
                    all_data.extend(j)
                    # print(j)
                else:
                    # print("jj",j)
                    all_data.append(j)
        print(all_data)
                #     for m in j.split():
                #         print("mmm",m)
                #         if m==";":
                #             pass
                #         else:
                #             all_data.append(m)
                # else:
                #     all_data.append(j)
               
                # print(all_data)
                    # cur.execute("insert into carbon_nanotube values({value})".format(value=(all_data)))
                
    # cur.close()
    # mydb.commit()
    # mydb.close()
                    
        # print(i)
# Out:
# []
# ['2', '1', '0', '679005', '0', '701318', '0', '017033', '0', '721039', '0', '730232', '0', '017014']
# ['2', '1', '0', '717298', '0', '642129', '0', '231319', '0', '738414', '0', '65675', '0', '232369']
# ['2', '1', '0', '489336', '0', '303751', '0', '088462', '0', '477676', '0', '263221', '0', '088712']
# ['2', '1', '0', '413957', '0', '632996', '0', '040843', '0', '408823', '0', '657897', '0', '039796']
# ['2', '1', '0', '334292', '0', '543401', '0', '15989', '0', '303349', '0', '558807', '0', '157373']
# ['2', '1', '0', '510664', '0', '696249', '0', '255128', '0', '496977', '0', '725608', '0', '25597']
# ['2', '1', '0', '413957', '0', '632996', '0', '374176', '0', '390878', '0', '657645', '0', '374735']
# ['2', '1', '0', '712552', '0', '55479', '0', '112271', '0', '750056', '0', '561494', '0', '114944']
# ['2', '1', '0', '320995', '0', '298682', '0', '1837', '0', '281301', '0', '261433', '0', '182779']
# ...

# %%
mydb=connection.connect(host="localhost",database="student",user="abc",passwd="password",use_pure=True)

a =pd.read_sql("select * from carbon_nanotube",mydb)
a
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [15], line 1
# ----> 1 mydb=connection.connect(host="localhost",database="student",user="abc",passwd="password",use_pure=True)
#       3 a =pd.read_sql("select * from carbon_nanotube",mydb)
#       4 a
#
# AttributeError: module 'mysql.connector.connection' has no attribute 'connect'
